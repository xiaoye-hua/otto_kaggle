# %% [markdown]
# In this notebook we will train an LGBM Ranker.
#
# In his very informative post, [Recommendation Systems for Large Datasets](https://www.kaggle.com/competitions/otto-recommender-system/discussion/364721) [@ravishah1](https://www.kaggle.com/ravishah1) explains how re-ranking models are the industry standard for dealing with datasets like we are presented with in this competition, that is ones with high cardinality categories!
#
# Earlier in this competition I shared a notebook [co-visitation matrix - simplified, imprvd logic 🔥](https://www.kaggle.com/code/radek1/co-visitation-matrix-simplified-imprvd-logic) which introduces the co-visitation matrix that can be used for candidate generation and scoring. (to read more about co-visitation matrices and how they work, please see [💡 What is the co-visiation matrix, really?](https://www.kaggle.com/competitions/otto-recommender-system/discussion/365358))
#
# Here, we will only look at ranking. I don't expect this notebook to achieve a particularly good score, but it will provide all the low level plumbing needed for training ranking models. One will be able to build on it and improve the result (via for instance adding new candidates generated using co-visitation matrices!).
#
# For data processing we will use [polars](https://www.pola.rs/). Polars is a very interesting library that I wanted to try for a very long time now. It is written in Rust and embraces running on multiple cores. And I must say it delivers! I liked the API quite a bit and its speed (though in that department `cudf` would still be my first choice!). I am however not touching my GPU quata on Kaggle just yet as I have a couple of things lined up that I would like to share with you that definitely will require the GPU! 🙂
#
# To simplify the code, I am using a version of the dataset that I shared [here](https://www.kaggle.com/datasets/radek1/otto-train-and-test-data-for-local-validation). No need for dealing with `jsonl` files any longer as it's all `parquet` files now! (Specifically, I am using a version of this dataset that I preprared for local validation [in this notebook](https://www.kaggle.com/code/radek1/a-robust-local-validation-framework).)
#
# ## Other resources you might find useful:
#
#
# * [💡 [2 methods] How-to ensemble predictions 🏅🏅🏅](https://www.kaggle.com/code/radek1/2-methods-how-to-ensemble-predictions)
# * [📖 What are some good resources to learn about how gradient-boosted tree ranking models work?](https://www.kaggle.com/competitions/otto-recommender-system/discussion/366477)
# * [💡What is a good initial goal in the competition? How to improve beyond it? 📈](https://www.kaggle.com/competitions/otto-recommender-system/discussion/368685)
# * [💡How to improve the results of your Approximate Nearest Neighbor search! (annoy)](https://www.kaggle.com/competitions/otto-recommender-system/discussion/368385)
# * [from zero to 60 in 2 seconds or less 🏎️🚓🚓🚓](https://www.kaggle.com/competitions/otto-recommender-system/discussion/367058)

# %% [markdown]
# # Config

# %%
debug = False

type2id = {"clicks": 0, "carts": 1, "orders": 2}
# id2type = dict(zip(type2id.values(), type2id.keys()))
model_file = '../model_training/ranker.pkl'

test_candidate_file = '../data/test_candidates.csv'
final_submission_file = '../data/final_submission.csv'

feature_cols = ['aid', 'type', 'action_num_reverse_chrono', 'session_length', 'log_recency_score',
#                 'type_weighted_log_recency_score'
               ]
target = 'gt'

# %% [markdown]
# # Data Processing

# %%
import polars as pl
import glob
import pandas as pd
import gc
from sklearn.pipeline import Pipeline
import joblib

# %%
! ls ../out/
# Out:
# debug_submission.csv      test_labels.jsonl         train_sessions.jsonl
# debug_test_labels.jsonl   test_sessions.jsonl
# debug_test_sessions.jsonl test_sessions_full.jsonl

# %% [markdown]
# # Function

# %%
def get_session(row):
    session = row
#     print(session)
    return session.split('_')[0]
def get_type(row):
    session = row
#     print(session)
    return session.split('_')[1]
def data_preprocess(train):
    return train.with_columns(
                [
                    pl.col('labels').str.split(' '),
        #             pl.col('session_type').str.split('_').map(lambda s: s[0]),
                    pl.col('session_type').apply(lambda s: get_session(s)).alias('session'),
                    pl.col('session_type').apply(lambda s: get_type(s)).alias('type')
                ]
            ).explode('labels').with_columns(
                [
                    pl.col('labels').cast(pl.datatypes.Int32).alias('aid'),
                     pl.col('session').cast(pl.datatypes.Int32),
                    pl.col('type').apply(lambda x: type2id[x])
                ]
            ).drop(['session_type', 'labels']).with_columns(
                [
                    pl.col('session').cast(pl.datatypes.Int32),
                    pl.col('type').cast(pl.datatypes.UInt8),
                    pl.col('aid').cast(pl.datatypes.Int32)
                ]
            )
    

def add_action_num_reverse_chrono(df):
    return df.select([
        pl.col('*'),
        pl.col('session').cumcount().reverse().over('session').alias('action_num_reverse_chrono')
    ])

def add_session_length(df):
    return df.select([
        pl.col('*'),
        pl.col('session').count().over('session').alias('session_length')
    ])

def add_log_recency_score(df):
    linear_interpolation = 0.1 + ((1-0.1) / (df['session_length']-1)) * (df['session_length']-df['action_num_reverse_chrono']-1)
    return df.with_columns(pl.Series(2**linear_interpolation - 1).alias('log_recency_score')).fill_nan(1)

# def add_type_weighted_log_recency_score(df):
#     type_weights = {0:1, 1:6, 2:3}
#     type_weighted_log_recency_score = pl.Series(df['log_recency_score'] / df['type'].apply(lambda x: type_weights[x]))
#     return df.with_column(type_weighted_log_recency_score.alias('type_weighted_log_recency_score'))

def apply(df, pipeline):
    for f in pipeline:
        df = f(df)
    return df

pipeline = [ data_preprocess, add_action_num_reverse_chrono, add_session_length, add_log_recency_score, 
#             add_type_weighted_log_recency_score
           ]

# %% [markdown]
# # Codes

# %%
if debug: 
    train = pl.read_csv('../out/debug_submission.csv')
else:
    train = pl.read_csv('../data/val_candidates.csv')
# train = pl.read_parquet('../data/explode_debug.parquet')
train_labels = pl.read_parquet('../data/parquet/val/test_labels.parquet')

# %%
train.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ 11098532_clicks ┆ 876469 7651 108125 1202618 77906... │
# └─────────────────┴─────────────────────────────────────┘

# %%
train.shape
# Out:
# (5403753, 2)

# %%
# # train['labels'] = 
# # train = 
# train = (
#     train.with_columns(
#         [
#             pl.col('session').alias('session_type')
#         ])
#     .drop(['session', '__index_level_0__'])
#     .with_columns(
#         [
# #             pl.col('labels').str.split(' '),
# #             pl.col('session_type').str.split('_').map(lambda s: s[0])
#             pl.col('session_type').apply(lambda s: get_session(s)).alias('session'),
#             pl.col('session_type').apply(lambda s: get_type(s)).alias('type')
# #             pl.col("session_type").arr().get(0).alias("a"),
#         ]
#     )
#     .explode('labels')
#     .with_columns(
#         [
#             pl.col('labels').cast(pl.datatypes.Int32).alias('aid'),
#              pl.col('session').cast(pl.datatypes.Int32),
#             pl.col('type').apply(lambda x: type2id[x])
#         ]
#     )
#     .drop(['session_type', 'labels'])
#     .with_columns(
#         [
#             pl.col('session').cast(pl.datatypes.Int32),
#             pl.col('type').cast(pl.datatypes.UInt8),
#             pl.col('aid').cast(pl.datatypes.Int32)
#         ]
#     )
    
# )
# # .with_columns(
# #     [
# #         pl.col('session_type').alias('new')
# #     ]
# # )
# # .with_columns(
# #     [
# #         pl.col('session_type').get(0)
# #     ]
# # )

# %%
train.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ 11098532_clicks ┆ 876469 7651 108125 1202618 77906... │
# └─────────────────┴─────────────────────────────────────┘

# %%
# train =

# %%
train.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ 11098532_clicks ┆ 876469 7651 108125 1202618 77906... │
# └─────────────────┴─────────────────────────────────────┘

# %%
# transformed_train.apply(lambda row: get_session(row))

# %%
print(f"{train.shape}; {train_labels.shape}")
# Out:
# (5403753, 2); (2212692, 3)

# %%
train.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ 11098532_clicks ┆ 876469 7651 108125 1202618 77906... │
# └─────────────────┴─────────────────────────────────────┘

# %%
# train = train.drop('ts')

# %%
train_labels.head()
# Out:
# shape: (5, 3)
# ┌──────────┬────────┬───────────────────────────────┐
# │ session  ┆ type   ┆ ground_truth                  │
# │ ---      ┆ ---    ┆ ---                           │
# │ i64      ┆ str    ┆ list[i64]                     │
# ╞══════════╪════════╪═══════════════════════════════╡
# │ 11098528 ┆ clicks ┆ [1679529]                     │
# │ 11098528 ┆ carts  ┆ [1199737]                     │
# │ 11098528 ┆ orders ┆ [990658, 950341, ... 1033148] │
# │ 11098529 ┆ clicks ┆ [1105029]                     │
# │ 11098530 ┆ orders ┆ [409236]                      │
# └──────────┴────────┴───────────────────────────────┘

# %%
train.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ 11098532_clicks ┆ 876469 7651 108125 1202618 77906... │
# └─────────────────┴─────────────────────────────────────┘

# %%
train_labels.shape
# Out:
# (2212692, 3)

# %% [markdown]
# We are calculating the scores that we used for creating co-vistation matrices! We know they carry signal, so let's provde this information to our `LGBM Ranker`!

# %%
train.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ 11098532_clicks ┆ 876469 7651 108125 1202618 77906... │
# └─────────────────┴─────────────────────────────────────┘

# %%
train.head(100)
# Out:
# shape: (100, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 11098528_clicks ┆ 11830 588923 1732105 571762 8761... │
# │ 11098529_clicks ┆ 1105029 634024 1632356 1843848 1... │
# │ 11098530_clicks ┆ 409236 264500 1603001 583026 963... │
# │ 11098531_clicks ┆ 396199 1271998 452188 1728212 13... │
# │ ...             ┆ ...                                 │
# │ 11098624_clicks ┆ 1122221 1160655 215084 1824869 1... │
# │ 11098625_clicks ┆ 451041 1030865 605680 1324815 13... │
# │ 11098626_clicks ┆ 93213 1602567 1813308 477493 923... │
# │ 11098627_clicks ┆ 1063957 1833274 84823 1182494 16... │
# └─────────────────┴─────────────────────────────────────┘

# %%
train = apply(train, pipeline)

# %% [markdown]
# All done!

# %%
train.head()
# Out:
# shape: (5, 6)
# ┌──────────┬──────┬─────────┬───────────────────────────┬────────────────┬───────────────────┐
# │ session  ┆ type ┆ aid     ┆ action_num_reverse_chrono ┆ session_length ┆ log_recency_score │
# │ ---      ┆ ---  ┆ ---     ┆ ---                       ┆ ---            ┆ ---               │
# │ i32      ┆ u8   ┆ i32     ┆ u32                       ┆ u32            ┆ f64               │
# ╞══════════╪══════╪═════════╪═══════════════════════════╪════════════════╪═══════════════════╡
# │ 11098528 ┆ 0    ┆ 11830   ┆ 52                        ┆ 53             ┆ 0.071773          │
# │ 11098528 ┆ 0    ┆ 588923  ┆ 51                        ┆ 53             ┆ 0.084709          │
# │ 11098528 ┆ 0    ┆ 1732105 ┆ 50                        ┆ 53             ┆ 0.0978            │
# │ 11098528 ┆ 0    ┆ 571762  ┆ 49                        ┆ 53             ┆ 0.111049          │
# │ 11098528 ┆ 0    ┆ 876129  ┆ 48                        ┆ 53             ┆ 0.124459          │
# └──────────┴──────┴─────────┴───────────────────────────┴────────────────┴───────────────────┘

# %%
train.shape
# Out:
# (142104561, 6)

# %%
train['type'].value_counts()
# Out:
# shape: (3, 2)
# ┌──────┬──────────┐
# │ type ┆ counts   │
# │ ---  ┆ ---      │
# │ u8   ┆ u32      │
# ╞══════╪══════════╡
# │ 0    ┆ 51639967 │
# │ 2    ┆ 45232297 │
# │ 1    ┆ 45232297 │
# └──────┴──────────┘

# %% [markdown]
# Now we need to process our labels a little bit and merge them onto our train set.

# %%
train_labels = train_labels.explode('ground_truth').with_columns([
    pl.col('ground_truth').alias('aid'),
    pl.col('type').apply(lambda x: type2id[x])
])[['session', 'type', 'aid']]

# %%
train_labels.shape
# Out:
# (2650372, 3)

# %%
train_labels.head()
# Out:
# shape: (5, 3)
# ┌──────────┬──────┬─────────┐
# │ session  ┆ type ┆ aid     │
# │ ---      ┆ ---  ┆ ---     │
# │ i64      ┆ i64  ┆ i64     │
# ╞══════════╪══════╪═════════╡
# │ 11098528 ┆ 0    ┆ 1679529 │
# │ 11098528 ┆ 1    ┆ 1199737 │
# │ 11098528 ┆ 2    ┆ 990658  │
# │ 11098528 ┆ 2    ┆ 950341  │
# │ 11098528 ┆ 2    ┆ 1462506 │
# └──────────┴──────┴─────────┘

# %%
train_labels = train_labels.with_columns([
    pl.col('session').cast(pl.datatypes.Int32),
    pl.col('type').cast(pl.datatypes.UInt8),
    pl.col('aid').cast(pl.datatypes.Int32)
])

# %%
train_labels = train_labels.with_column(pl.lit(1).alias('gt'))

# %%
train_labels.head()
# Out:
# shape: (5, 4)
# ┌──────────┬──────┬─────────┬─────┐
# │ session  ┆ type ┆ aid     ┆ gt  │
# │ ---      ┆ ---  ┆ ---     ┆ --- │
# │ i32      ┆ u8   ┆ i32     ┆ i32 │
# ╞══════════╪══════╪═════════╪═════╡
# │ 11098528 ┆ 0    ┆ 1679529 ┆ 1   │
# │ 11098528 ┆ 1    ┆ 1199737 ┆ 1   │
# │ 11098528 ┆ 2    ┆ 990658  ┆ 1   │
# │ 11098528 ┆ 2    ┆ 950341  ┆ 1   │
# │ 11098528 ┆ 2    ┆ 1462506 ┆ 1   │
# └──────────┴──────┴─────────┴─────┘

# %%
train_labels['gt'].value_counts()
# Out:
# shape: (1, 2)
# ┌─────┬─────────┐
# │ gt  ┆ counts  │
# │ --- ┆ ---     │
# │ i32 ┆ u32     │
# ╞═════╪═════════╡
# │ 1   ┆ 2650372 │
# └─────┴─────────┘

# %%
train = train.join(train_labels, how='left', on=['session', 'type', 'aid']).with_column(pl.col('gt').fill_null(0))

# %%
train.head()
# Out:
# shape: (5, 7)
# ┌──────────┬──────┬─────────┬───────────────────────────┬────────────────┬───────────────────┬─────┐
# │ session  ┆ type ┆ aid     ┆ action_num_reverse_chrono ┆ session_length ┆ log_recency_score ┆ gt  │
# │ ---      ┆ ---  ┆ ---     ┆ ---                       ┆ ---            ┆ ---               ┆ --- │
# │ i32      ┆ u8   ┆ i32     ┆ u32                       ┆ u32            ┆ f64               ┆ i32 │
# ╞══════════╪══════╪═════════╪═══════════════════════════╪════════════════╪═══════════════════╪═════╡
# │ 11098528 ┆ 0    ┆ 11830   ┆ 52                        ┆ 53             ┆ 0.071773          ┆ 0   │
# │ 11098528 ┆ 0    ┆ 588923  ┆ 51                        ┆ 53             ┆ 0.084709          ┆ 0   │
# │ 11098528 ┆ 0    ┆ 1732105 ┆ 50                        ┆ 53             ┆ 0.0978            ┆ 0   │
# │ 11098528 ┆ 0    ┆ 571762  ┆ 49                        ┆ 53             ┆ 0.111049          ┆ 0   │
# │ 11098528 ┆ 0    ┆ 876129  ┆ 48                        ┆ 53             ┆ 0.124459          ┆ 0   │
# └──────────┴──────┴─────────┴───────────────────────────┴────────────────┴───────────────────┴─────┘

# %%
type2id
# Out:
# {'clicks': 0, 'carts': 1, 'orders': 2}

# %%
# train['type']

# %%
# train[train['type']==2]#['gt'].value_counts()

# %%
train['gt'].value_counts()
# Out:
# shape: (2, 2)
# ┌─────┬───────────┐
# │ gt  ┆ counts    │
# │ --- ┆ ---       │
# │ i32 ┆ u32       │
# ╞═════╪═══════════╡
# │ 0   ┆ 140605321 │
# │ 1   ┆ 1499240   │
# └─────┴───────────┘

# %% [markdown]
# Ok, so we now have our preprocessed dataset, a column with ground truth, which means that the only thing we are missing for our Ranker is... information how to group individual rows into sessions!

# %%
train.shape
# Out:
# (142104561, 7)

# %%
train.head()
# Out:
# shape: (5, 7)
# ┌──────────┬──────┬─────────┬───────────────────────────┬────────────────┬───────────────────┬─────┐
# │ session  ┆ type ┆ aid     ┆ action_num_reverse_chrono ┆ session_length ┆ log_recency_score ┆ gt  │
# │ ---      ┆ ---  ┆ ---     ┆ ---                       ┆ ---            ┆ ---               ┆ --- │
# │ i32      ┆ u8   ┆ i32     ┆ u32                       ┆ u32            ┆ f64               ┆ i32 │
# ╞══════════╪══════╪═════════╪═══════════════════════════╪════════════════╪═══════════════════╪═════╡
# │ 11098528 ┆ 0    ┆ 11830   ┆ 52                        ┆ 53             ┆ 0.071773          ┆ 0   │
# │ 11098528 ┆ 0    ┆ 588923  ┆ 51                        ┆ 53             ┆ 0.084709          ┆ 0   │
# │ 11098528 ┆ 0    ┆ 1732105 ┆ 50                        ┆ 53             ┆ 0.0978            ┆ 0   │
# │ 11098528 ┆ 0    ┆ 571762  ┆ 49                        ┆ 53             ┆ 0.111049          ┆ 0   │
# │ 11098528 ┆ 0    ┆ 876129  ┆ 48                        ┆ 53             ┆ 0.124459          ┆ 0   │
# └──────────┴──────┴─────────┴───────────────────────────┴────────────────┴───────────────────┴─────┘

# %%
def get_session_lenghts(df):
    return df.groupby('session').agg([
        pl.col('session').count().alias('session_length')
    ])['session_length'].to_numpy()

# %%
session_lengths_train = get_session_lenghts(train)

# %%
session_lengths_train.shape
# Out:
# (1801251,)

# %%
session_lengths_train
# Out:
# array([  3,  53, 120, ..., 105, 120, 120], dtype=uint32)

# %% [markdown]
# # Model training

# %%
import lightgbm

# %%
from lightgbm.sklearn import LGBMRanker

# %%
ranker = LGBMRanker(
    objective="lambdarank",
    metric="ndcg",
    boosting_type="dart",
    n_estimators=100,
    importance_type='gain',
    eval_at=[5]
)

# %%
# train[feature_cols]

# %%
ranker = ranker.fit(
    X=train[feature_cols].to_pandas(),
    y=train[target].to_pandas(),
    group=session_lengths_train,
    eval_set=[(train[feature_cols].to_pandas(), train[target].to_pandas())],
    eval_group=[session_lengths_train]
)
# Out:
# [1]	valid_0's ndcg@1: 0.663897	valid_0's ndcg@2: 0.680538	valid_0's ndcg@3: 0.699604	valid_0's ndcg@4: 0.714222	valid_0's ndcg@5: 0.725929
# [2]	valid_0's ndcg@1: 0.669665	valid_0's ndcg@2: 0.687172	valid_0's ndcg@3: 0.705388	valid_0's ndcg@4: 0.719791	valid_0's ndcg@5: 0.730201
# [3]	valid_0's ndcg@1: 0.670806	valid_0's ndcg@2: 0.688729	valid_0's ndcg@3: 0.706955	valid_0's ndcg@4: 0.721182	valid_0's ndcg@5: 0.731471
# [4]	valid_0's ndcg@1: 0.67072	valid_0's ndcg@2: 0.688837	valid_0's ndcg@3: 0.707043	valid_0's ndcg@4: 0.721324	valid_0's ndcg@5: 0.731529
# [5]	valid_0's ndcg@1: 0.670911	valid_0's ndcg@2: 0.689083	valid_0's ndcg@3: 0.707252	valid_0's ndcg@4: 0.721551	valid_0's ndcg@5: 0.731762
# [6]	valid_0's ndcg@1: 0.671056	valid_0's ndcg@2: 0.689381	valid_0's ndcg@3: 0.707483	valid_0's ndcg@4: 0.721677	valid_0's ndcg@5: 0.731844
# [7]	valid_0's ndcg@1: 0.671329	valid_0's ndcg@2: 0.689659	valid_0's ndcg@3: 0.707722	valid_0's ndcg@4: 0.721838	valid_0's ndcg@5: 0.731971
# [8]	valid_0's ndcg@1: 0.671676	valid_0's ndcg@2: 0.690047	valid_0's ndcg@3: 0.708032	valid_0's ndcg@4: 0.722137	valid_0's ndcg@5: 0.732254
# [9]	valid_0's ndcg@1: 0.672312	valid_0's ndcg@2: 0.690341	valid_0's ndcg@3: 0.708344	valid_0's ndcg@4: 0.722391	valid_0's ndcg@5: 0.732549
# [10]	valid_0's ndcg@1: 0.672325	valid_0's ndcg@2: 0.690312	valid_0's ndcg@3: 0.708303	valid_0's ndcg@4: 0.722335	valid_0's ndcg@5: 0.732488
# [11]	valid_0's ndcg@1: 0.671981	valid_0's ndcg@2: 0.69002	valid_0's ndcg@3: 0.708104	valid_0's ndcg@4: 0.722169	valid_0's ndcg@5: 0.732334
# [12]	valid_0's ndcg@1: 0.67195	valid_0's ndcg@2: 0.690025	valid_0's ndcg@3: 0.708085	valid_0's ndcg@4: 0.722179	valid_0's ndcg@5: 0.732338
# [13]	valid_0's ndcg@1: 0.67236	valid_0's ndcg@2: 0.690237	valid_0's ndcg@3: 0.708178	valid_0's ndcg@4: 0.722261	valid_0's ndcg@5: 0.73243
# [14]	valid_0's ndcg@1: 0.672241	valid_0's ndcg@2: 0.690132	valid_0's ndcg@3: 0.708124	valid_0's ndcg@4: 0.722202	valid_0's ndcg@5: 0.732403
# [15]	valid_0's ndcg@1: 0.672556	valid_0's ndcg@2: 0.69046	valid_0's ndcg@3: 0.708394	valid_0's ndcg@4: 0.722452	valid_0's ndcg@5: 0.732576
# [16]	valid_0's ndcg@1: 0.67255	valid_0's ndcg@2: 0.690526	valid_0's ndcg@3: 0.708465	valid_0's ndcg@4: 0.722472	valid_0's ndcg@5: 0.732589
# [17]	valid_0's ndcg@1: 0.6729	valid_0's ndcg@2: 0.690671	valid_0's ndcg@3: 0.708521	valid_0's ndcg@4: 0.722545	valid_0's ndcg@5: 0.732723
# [18]	valid_0's ndcg@1: 0.672947	valid_0's ndcg@2: 0.690695	valid_0's ndcg@3: 0.708539	valid_0's ndcg@4: 0.722569	valid_0's ndcg@5: 0.732737
# [19]	valid_0's ndcg@1: 0.673107	valid_0's ndcg@2: 0.690832	valid_0's ndcg@3: 0.70863	valid_0's ndcg@4: 0.722648	valid_0's ndcg@5: 0.732829
# [20]	valid_0's ndcg@1: 0.673244	valid_0's ndcg@2: 0.690897	valid_0's ndcg@3: 0.708704	valid_0's ndcg@4: 0.722697	valid_0's ndcg@5: 0.732896
# [21]	valid_0's ndcg@1: 0.673272	valid_0's ndcg@2: 0.690925	valid_0's ndcg@3: 0.708709	valid_0's ndcg@4: 0.722723	valid_0's ndcg@5: 0.732906
# [22]	valid_0's ndcg@1: 0.673168	valid_0's ndcg@2: 0.690897	valid_0's ndcg@3: 0.708727	valid_0's ndcg@4: 0.722694	valid_0's ndcg@5: 0.732879
# [23]	valid_0's ndcg@1: 0.673217	valid_0's ndcg@2: 0.690907	valid_0's ndcg@3: 0.708706	valid_0's ndcg@4: 0.722714	valid_0's ndcg@5: 0.73289
# [24]	valid_0's ndcg@1: 0.673327	valid_0's ndcg@2: 0.690902	valid_0's ndcg@3: 0.708736	valid_0's ndcg@4: 0.722736	valid_0's ndcg@5: 0.732927
# [25]	valid_0's ndcg@1: 0.67339	valid_0's ndcg@2: 0.690981	valid_0's ndcg@3: 0.708807	valid_0's ndcg@4: 0.722781	valid_0's ndcg@5: 0.732966
# [26]	valid_0's ndcg@1: 0.673444	valid_0's ndcg@2: 0.691022	valid_0's ndcg@3: 0.70883	valid_0's ndcg@4: 0.722809	valid_0's ndcg@5: 0.732992
# [27]	valid_0's ndcg@1: 0.673373	valid_0's ndcg@2: 0.690968	valid_0's ndcg@3: 0.708816	valid_0's ndcg@4: 0.722819	valid_0's ndcg@5: 0.732986
# [28]	valid_0's ndcg@1: 0.67337	valid_0's ndcg@2: 0.690989	valid_0's ndcg@3: 0.708845	valid_0's ndcg@4: 0.722843	valid_0's ndcg@5: 0.733022
# [29]	valid_0's ndcg@1: 0.673621	valid_0's ndcg@2: 0.69123	valid_0's ndcg@3: 0.709039	valid_0's ndcg@4: 0.723002	valid_0's ndcg@5: 0.733187
# [30]	valid_0's ndcg@1: 0.673648	valid_0's ndcg@2: 0.69124	valid_0's ndcg@3: 0.709031	valid_0's ndcg@4: 0.723016	valid_0's ndcg@5: 0.733192
# [31]	valid_0's ndcg@1: 0.673629	valid_0's ndcg@2: 0.691228	valid_0's ndcg@3: 0.70903	valid_0's ndcg@4: 0.723025	valid_0's ndcg@5: 0.733205
# [32]	valid_0's ndcg@1: 0.673651	valid_0's ndcg@2: 0.691225	valid_0's ndcg@3: 0.709036	valid_0's ndcg@4: 0.723036	valid_0's ndcg@5: 0.733244
# [33]	valid_0's ndcg@1: 0.673292	valid_0's ndcg@2: 0.690946	valid_0's ndcg@3: 0.708841	valid_0's ndcg@4: 0.722896	valid_0's ndcg@5: 0.733109
# [34]	valid_0's ndcg@1: 0.673305	valid_0's ndcg@2: 0.690961	valid_0's ndcg@3: 0.708852	valid_0's ndcg@4: 0.722908	valid_0's ndcg@5: 0.733124
# [35]	valid_0's ndcg@1: 0.673438	valid_0's ndcg@2: 0.691012	valid_0's ndcg@3: 0.708892	valid_0's ndcg@4: 0.722951	valid_0's ndcg@5: 0.733169
# [36]	valid_0's ndcg@1: 0.673562	valid_0's ndcg@2: 0.691057	valid_0's ndcg@3: 0.708932	valid_0's ndcg@4: 0.722989	valid_0's ndcg@5: 0.733211
# [37]	valid_0's ndcg@1: 0.673612	valid_0's ndcg@2: 0.691106	valid_0's ndcg@3: 0.708947	valid_0's ndcg@4: 0.723007	valid_0's ndcg@5: 0.733231
# [38]	valid_0's ndcg@1: 0.673798	valid_0's ndcg@2: 0.691206	valid_0's ndcg@3: 0.709106	valid_0's ndcg@4: 0.723131	valid_0's ndcg@5: 0.73335
# [39]	valid_0's ndcg@1: 0.673831	valid_0's ndcg@2: 0.69132	valid_0's ndcg@3: 0.70915	valid_0's ndcg@4: 0.723171	valid_0's ndcg@5: 0.733385
# [40]	valid_0's ndcg@1: 0.673805	valid_0's ndcg@2: 0.691324	valid_0's ndcg@3: 0.709153	valid_0's ndcg@4: 0.723166	valid_0's ndcg@5: 0.73338
# [41]	valid_0's ndcg@1: 0.673816	valid_0's ndcg@2: 0.691327	valid_0's ndcg@3: 0.70915	valid_0's ndcg@4: 0.723161	valid_0's ndcg@5: 0.733385
# [42]	valid_0's ndcg@1: 0.67418	valid_0's ndcg@2: 0.691471	valid_0's ndcg@3: 0.709234	valid_0's ndcg@4: 0.723237	valid_0's ndcg@5: 0.733472
# [43]	valid_0's ndcg@1: 0.674171	valid_0's ndcg@2: 0.691464	valid_0's ndcg@3: 0.709228	valid_0's ndcg@4: 0.723229	valid_0's ndcg@5: 0.73346
# [44]	valid_0's ndcg@1: 0.674243	valid_0's ndcg@2: 0.691493	valid_0's ndcg@3: 0.709235	valid_0's ndcg@4: 0.723245	valid_0's ndcg@5: 0.733467
# [45]	valid_0's ndcg@1: 0.674131	valid_0's ndcg@2: 0.69141	valid_0's ndcg@3: 0.709153	valid_0's ndcg@4: 0.723187	valid_0's ndcg@5: 0.733429
# [46]	valid_0's ndcg@1: 0.673998	valid_0's ndcg@2: 0.69135	valid_0's ndcg@3: 0.709116	valid_0's ndcg@4: 0.723154	valid_0's ndcg@5: 0.733389
# [47]	valid_0's ndcg@1: 0.674194	valid_0's ndcg@2: 0.691551	valid_0's ndcg@3: 0.709305	valid_0's ndcg@4: 0.723308	valid_0's ndcg@5: 0.73354
# [48]	valid_0's ndcg@1: 0.674209	valid_0's ndcg@2: 0.691447	valid_0's ndcg@3: 0.709267	valid_0's ndcg@4: 0.723283	valid_0's ndcg@5: 0.733524
# [49]	valid_0's ndcg@1: 0.67419	valid_0's ndcg@2: 0.691545	valid_0's ndcg@3: 0.709304	valid_0's ndcg@4: 0.723301	valid_0's ndcg@5: 0.733543
# [50]	valid_0's ndcg@1: 0.674198	valid_0's ndcg@2: 0.691415	valid_0's ndcg@3: 0.709251	valid_0's ndcg@4: 0.723269	valid_0's ndcg@5: 0.733514
# [51]	valid_0's ndcg@1: 0.674198	valid_0's ndcg@2: 0.691439	valid_0's ndcg@3: 0.709268	valid_0's ndcg@4: 0.723277	valid_0's ndcg@5: 0.733514
# [52]	valid_0's ndcg@1: 0.674214	valid_0's ndcg@2: 0.691573	valid_0's ndcg@3: 0.709325	valid_0's ndcg@4: 0.723313	valid_0's ndcg@5: 0.733538
# [53]	valid_0's ndcg@1: 0.674178	valid_0's ndcg@2: 0.691549	valid_0's ndcg@3: 0.709314	valid_0's ndcg@4: 0.723304	valid_0's ndcg@5: 0.73353
# [54]	valid_0's ndcg@1: 0.674004	valid_0's ndcg@2: 0.69137	valid_0's ndcg@3: 0.709102	valid_0's ndcg@4: 0.723093	valid_0's ndcg@5: 0.73334
# [55]	valid_0's ndcg@1: 0.673924	valid_0's ndcg@2: 0.691173	valid_0's ndcg@3: 0.708983	valid_0's ndcg@4: 0.723069	valid_0's ndcg@5: 0.733339
# [56]	valid_0's ndcg@1: 0.674134	valid_0's ndcg@2: 0.691363	valid_0's ndcg@3: 0.709162	valid_0's ndcg@4: 0.723204	valid_0's ndcg@5: 0.733464
# [57]	valid_0's ndcg@1: 0.674258	valid_0's ndcg@2: 0.691521	valid_0's ndcg@3: 0.709328	valid_0's ndcg@4: 0.723323	valid_0's ndcg@5: 0.733568
# [58]	valid_0's ndcg@1: 0.674076	valid_0's ndcg@2: 0.691446	valid_0's ndcg@3: 0.709206	valid_0's ndcg@4: 0.723221	valid_0's ndcg@5: 0.733482
# [59]	valid_0's ndcg@1: 0.674075	valid_0's ndcg@2: 0.691441	valid_0's ndcg@3: 0.709204	valid_0's ndcg@4: 0.723218	valid_0's ndcg@5: 0.733482
# [60]	valid_0's ndcg@1: 0.674129	valid_0's ndcg@2: 0.691419	valid_0's ndcg@3: 0.709158	valid_0's ndcg@4: 0.723145	valid_0's ndcg@5: 0.733426
# [61]	valid_0's ndcg@1: 0.675216	valid_0's ndcg@2: 0.691936	valid_0's ndcg@3: 0.709622	valid_0's ndcg@4: 0.723576	valid_0's ndcg@5: 0.733821
# [62]	valid_0's ndcg@1: 0.675255	valid_0's ndcg@2: 0.69194	valid_0's ndcg@3: 0.709618	valid_0's ndcg@4: 0.723586	valid_0's ndcg@5: 0.733829
# [63]	valid_0's ndcg@1: 0.675262	valid_0's ndcg@2: 0.691987	valid_0's ndcg@3: 0.709648	valid_0's ndcg@4: 0.723598	valid_0's ndcg@5: 0.733844
# [64]	valid_0's ndcg@1: 0.675066	valid_0's ndcg@2: 0.691817	valid_0's ndcg@3: 0.709438	valid_0's ndcg@4: 0.723394	valid_0's ndcg@5: 0.733674
# [65]	valid_0's ndcg@1: 0.675071	valid_0's ndcg@2: 0.691821	valid_0's ndcg@3: 0.70944	valid_0's ndcg@4: 0.723391	valid_0's ndcg@5: 0.733667
# [66]	valid_0's ndcg@1: 0.675201	valid_0's ndcg@2: 0.691963	valid_0's ndcg@3: 0.709621	valid_0's ndcg@4: 0.723581	valid_0's ndcg@5: 0.733829
# [67]	valid_0's ndcg@1: 0.675164	valid_0's ndcg@2: 0.691958	valid_0's ndcg@3: 0.709612	valid_0's ndcg@4: 0.723568	valid_0's ndcg@5: 0.733816
# [68]	valid_0's ndcg@1: 0.675047	valid_0's ndcg@2: 0.691839	valid_0's ndcg@3: 0.709426	valid_0's ndcg@4: 0.723383	valid_0's ndcg@5: 0.73365
# [69]	valid_0's ndcg@1: 0.675045	valid_0's ndcg@2: 0.691839	valid_0's ndcg@3: 0.709428	valid_0's ndcg@4: 0.723386	valid_0's ndcg@5: 0.733652
# [70]	valid_0's ndcg@1: 0.675064	valid_0's ndcg@2: 0.691858	valid_0's ndcg@3: 0.709443	valid_0's ndcg@4: 0.723398	valid_0's ndcg@5: 0.733653
# [71]	valid_0's ndcg@1: 0.675262	valid_0's ndcg@2: 0.692035	valid_0's ndcg@3: 0.709654	valid_0's ndcg@4: 0.723599	valid_0's ndcg@5: 0.733838
# [72]	valid_0's ndcg@1: 0.675055	valid_0's ndcg@2: 0.691797	valid_0's ndcg@3: 0.709422	valid_0's ndcg@4: 0.723374	valid_0's ndcg@5: 0.733653
# [73]	valid_0's ndcg@1: 0.675194	valid_0's ndcg@2: 0.69199	valid_0's ndcg@3: 0.709633	valid_0's ndcg@4: 0.72359	valid_0's ndcg@5: 0.733842
# [74]	valid_0's ndcg@1: 0.675205	valid_0's ndcg@2: 0.692026	valid_0's ndcg@3: 0.709638	valid_0's ndcg@4: 0.723606	valid_0's ndcg@5: 0.733846
# [75]	valid_0's ndcg@1: 0.675086	valid_0's ndcg@2: 0.691843	valid_0's ndcg@3: 0.709456	valid_0's ndcg@4: 0.723409	valid_0's ndcg@5: 0.733693
# [76]	valid_0's ndcg@1: 0.675079	valid_0's ndcg@2: 0.691791	valid_0's ndcg@3: 0.709426	valid_0's ndcg@4: 0.723382	valid_0's ndcg@5: 0.73367
# [77]	valid_0's ndcg@1: 0.675065	valid_0's ndcg@2: 0.691792	valid_0's ndcg@3: 0.709436	valid_0's ndcg@4: 0.723386	valid_0's ndcg@5: 0.733671
# [78]	valid_0's ndcg@1: 0.675277	valid_0's ndcg@2: 0.69199	valid_0's ndcg@3: 0.709662	valid_0's ndcg@4: 0.723607	valid_0's ndcg@5: 0.733858
# [79]	valid_0's ndcg@1: 0.674832	valid_0's ndcg@2: 0.691691	valid_0's ndcg@3: 0.709404	valid_0's ndcg@4: 0.723365	valid_0's ndcg@5: 0.733656
# [80]	valid_0's ndcg@1: 0.67502	valid_0's ndcg@2: 0.691885	valid_0's ndcg@3: 0.709633	valid_0's ndcg@4: 0.723589	valid_0's ndcg@5: 0.733857
# [81]	valid_0's ndcg@1: 0.675111	valid_0's ndcg@2: 0.691947	valid_0's ndcg@3: 0.70966	valid_0's ndcg@4: 0.723613	valid_0's ndcg@5: 0.73388
# [82]	valid_0's ndcg@1: 0.674873	valid_0's ndcg@2: 0.691692	valid_0's ndcg@3: 0.70937	valid_0's ndcg@4: 0.723345	valid_0's ndcg@5: 0.733632
# [83]	valid_0's ndcg@1: 0.674941	valid_0's ndcg@2: 0.691679	valid_0's ndcg@3: 0.709369	valid_0's ndcg@4: 0.723346	valid_0's ndcg@5: 0.733635
# [84]	valid_0's ndcg@1: 0.675177	valid_0's ndcg@2: 0.691849	valid_0's ndcg@3: 0.709504	valid_0's ndcg@4: 0.723441	valid_0's ndcg@5: 0.733731
# [85]	valid_0's ndcg@1: 0.675139	valid_0's ndcg@2: 0.691827	valid_0's ndcg@3: 0.709476	valid_0's ndcg@4: 0.723424	valid_0's ndcg@5: 0.733714
# [86]	valid_0's ndcg@1: 0.675297	valid_0's ndcg@2: 0.692047	valid_0's ndcg@3: 0.709696	valid_0's ndcg@4: 0.723653	valid_0's ndcg@5: 0.733905
# [87]	valid_0's ndcg@1: 0.675618	valid_0's ndcg@2: 0.692422	valid_0's ndcg@3: 0.710071	valid_0's ndcg@4: 0.723966	valid_0's ndcg@5: 0.734182
# [88]	valid_0's ndcg@1: 0.675726	valid_0's ndcg@2: 0.692469	valid_0's ndcg@3: 0.710094	valid_0's ndcg@4: 0.723987	valid_0's ndcg@5: 0.734207
# [89]	valid_0's ndcg@1: 0.675726	valid_0's ndcg@2: 0.692475	valid_0's ndcg@3: 0.710088	valid_0's ndcg@4: 0.723979	valid_0's ndcg@5: 0.734198
# [90]	valid_0's ndcg@1: 0.675721	valid_0's ndcg@2: 0.692484	valid_0's ndcg@3: 0.710099	valid_0's ndcg@4: 0.723987	valid_0's ndcg@5: 0.734208
# [91]	valid_0's ndcg@1: 0.675714	valid_0's ndcg@2: 0.692457	valid_0's ndcg@3: 0.710076	valid_0's ndcg@4: 0.723977	valid_0's ndcg@5: 0.734195
# [92]	valid_0's ndcg@1: 0.675513	valid_0's ndcg@2: 0.692227	valid_0's ndcg@3: 0.709841	valid_0's ndcg@4: 0.723763	valid_0's ndcg@5: 0.73398
# [93]	valid_0's ndcg@1: 0.675736	valid_0's ndcg@2: 0.692471	valid_0's ndcg@3: 0.710076	valid_0's ndcg@4: 0.723998	valid_0's ndcg@5: 0.734209
# [94]	valid_0's ndcg@1: 0.675756	valid_0's ndcg@2: 0.692481	valid_0's ndcg@3: 0.710091	valid_0's ndcg@4: 0.724003	valid_0's ndcg@5: 0.734215
# [95]	valid_0's ndcg@1: 0.675748	valid_0's ndcg@2: 0.692475	valid_0's ndcg@3: 0.71009	valid_0's ndcg@4: 0.723995	valid_0's ndcg@5: 0.734206
# [96]	valid_0's ndcg@1: 0.675708	valid_0's ndcg@2: 0.692468	valid_0's ndcg@3: 0.710073	valid_0's ndcg@4: 0.723986	valid_0's ndcg@5: 0.734191
# [97]	valid_0's ndcg@1: 0.675623	valid_0's ndcg@2: 0.692411	valid_0's ndcg@3: 0.710061	valid_0's ndcg@4: 0.724	valid_0's ndcg@5: 0.734179
# [98]	valid_0's ndcg@1: 0.675622	valid_0's ndcg@2: 0.692413	valid_0's ndcg@3: 0.710069	valid_0's ndcg@4: 0.723994	valid_0's ndcg@5: 0.734183
# [99]	valid_0's ndcg@1: 0.675402	valid_0's ndcg@2: 0.692228	valid_0's ndcg@3: 0.709793	valid_0's ndcg@4: 0.723766	valid_0's ndcg@5: 0.733978
# [100]	valid_0's ndcg@1: 0.675573	valid_0's ndcg@2: 0.692417	valid_0's ndcg@3: 0.710022	valid_0's ndcg@4: 0.723966	valid_0's ndcg@5: 0.73418

# %%
pipe = Pipeline([
    ('model', ranker)
])

# %%
joblib.dump(
    value=pipe,
    filename=model_file)
# Out:
# ['../model_training/ranker.pkl']

# %%
del train
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/c1/48j859bn141c_7299vlh4zjw0000gn/T/ipykernel_86628/954745029.py in <module>
# ----> 1 del train
#       2 gc.collect()
#
# NameError: name 'train' is not defined

# %% [markdown]
# # Load models

# %%
new_pipeline = joblib.load(
    filename=model_file
)

# %%
# ranker.predict(train[feature_cols].to_pandas(), raw_score=True)

# %%
# new_pipeline.predict(train[feature_cols].to_pandas(), raw_score=True)

# %%
new_pipeline
# Out:
# Pipeline(steps=[('model',
#                  LGBMRanker(boosting_type='dart', eval_at=[5],
#                             importance_type='gain', metric='ndcg',
#                             objective='lambdarank'))])

# %% [markdown]
# # Predict on test data

# %% [markdown]
# Let's load our test set, process it and predict on it.

# %%
test = pl.read_csv(test_candidate_file)

# %%
assert len(test['session_type'].unique()) == 5015409

# %%
test = apply(test, pipeline)

# %%
test.head()
# Out:
# shape: (5, 6)
# ┌──────────┬──────┬─────────┬───────────────────────────┬────────────────┬───────────────────┐
# │ session  ┆ type ┆ aid     ┆ action_num_reverse_chrono ┆ session_length ┆ log_recency_score │
# │ ---      ┆ ---  ┆ ---     ┆ ---                       ┆ ---            ┆ ---               │
# │ i32      ┆ u8   ┆ i32     ┆ u32                       ┆ u32            ┆ f64               │
# ╞══════════╪══════╪═════════╪═══════════════════════════╪════════════════╪═══════════════════╡
# │ 12899779 ┆ 0    ┆ 59625   ┆ 119                       ┆ 120            ┆ 0.071773          │
# │ 12899779 ┆ 0    ┆ 94230   ┆ 118                       ┆ 120            ┆ 0.077407          │
# │ 12899779 ┆ 0    ┆ 1253524 ┆ 117                       ┆ 120            ┆ 0.08307           │
# │ 12899779 ┆ 0    ┆ 1660529 ┆ 116                       ┆ 120            ┆ 0.088762          │
# │ 12899779 ┆ 0    ┆ 3295    ┆ 115                       ┆ 120            ┆ 0.094485          │
# └──────────┴──────┴─────────┴───────────────────────────┴────────────────┴───────────────────┘

# %%
assert len(test['session'].unique())*3 == 5015409

# %%
scores = new_pipeline.predict(test[feature_cols].to_pandas())

# %%
scores
# Out:
# array([ 0.36783401,  0.35013847, -0.21159791, ..., -1.98587036,
#        -1.97487119, -1.97487119])

# %%
scores.shape
# Out:
# (200616360,)

# %%
test.shape
# Out:
# (200616360, 6)

# %%
test.head()
# Out:
# shape: (5, 6)
# ┌──────────┬──────┬─────────┬───────────────────────────┬────────────────┬───────────────────┐
# │ session  ┆ type ┆ aid     ┆ action_num_reverse_chrono ┆ session_length ┆ log_recency_score │
# │ ---      ┆ ---  ┆ ---     ┆ ---                       ┆ ---            ┆ ---               │
# │ i32      ┆ u8   ┆ i32     ┆ u32                       ┆ u32            ┆ f64               │
# ╞══════════╪══════╪═════════╪═══════════════════════════╪════════════════╪═══════════════════╡
# │ 12899779 ┆ 0    ┆ 59625   ┆ 119                       ┆ 120            ┆ 0.071773          │
# │ 12899779 ┆ 0    ┆ 94230   ┆ 118                       ┆ 120            ┆ 0.077407          │
# │ 12899779 ┆ 0    ┆ 1253524 ┆ 117                       ┆ 120            ┆ 0.08307           │
# │ 12899779 ┆ 0    ┆ 1660529 ┆ 116                       ┆ 120            ┆ 0.088762          │
# │ 12899779 ┆ 0    ┆ 3295    ┆ 115                       ┆ 120            ┆ 0.094485          │
# └──────────┴──────┴─────────┴───────────────────────────┴────────────────┴───────────────────┘

# %% [markdown]
# # Create submission

# %%
test = test.with_columns(pl.Series(name='score', values=scores))
test_predictions = test.sort(['session', 'score'], reverse=True).groupby('session').agg([
    pl.col('aid').limit(20).list()
])

# %%
test_predictions.head()
# Out:
# shape: (5, 2)
# ┌──────────┬─────────────────────────────────┐
# │ session  ┆ aid                             │
# │ ---      ┆ ---                             │
# │ i32      ┆ list[i32]                       │
# ╞══════════╪═════════════════════════════════╡
# │ 14571581 ┆ [1100210, 1100210, ... 1158237] │
# │ 14571580 ┆ [202353, 202353, ... 433425]    │
# │ 14571579 ┆ [739876, 739876, ... 304799]    │
# │ 14571578 ┆ [519105, 519105, ... 822641]    │
# │ 14571577 ┆ [1141710, 1141710, ... 1666114] │
# └──────────┴─────────────────────────────────┘

# %%
session_types = []
labels = []

for session, preds in zip(test_predictions['session'].to_numpy(), test_predictions['aid'].to_numpy()):
    l = ' '.join(str(p) for p in preds)
    for session_type in ['clicks', 'carts', 'orders']:
        labels.append(l)
        session_types.append(f'{session}_{session_type}')

# %%
submission = pl.DataFrame({'session_type': session_types, 'labels': labels})
submission.write_csv(final_submission_file)

# %%
assert len(submission['session_type'].unique()) == 5015409

# %%
submission.head()
# Out:
# shape: (5, 2)
# ┌─────────────────┬─────────────────────────────────────┐
# │ session_type    ┆ labels                              │
# │ ---             ┆ ---                                 │
# │ str             ┆ str                                 │
# ╞═════════════════╪═════════════════════════════════════╡
# │ 14571581_clicks ┆ 1100210 1100210 1684953 462056 1... │
# │ 14571581_carts  ┆ 1100210 1100210 1684953 462056 1... │
# │ 14571581_orders ┆ 1100210 1100210 1684953 462056 1... │
# │ 14571580_clicks ┆ 202353 202353 1314576 441903 202... │
# │ 14571580_carts  ┆ 202353 202353 1314576 441903 202... │
# └─────────────────┴─────────────────────────────────────┘

# %%
submission.shape
# Out:
# (5015409, 2)

# %%
final_submission_file
# Out:
# '../data/final_submission.csv'

# %%
! ls -al ../data
# Out:
# total 8309912
# drwxr-xr-x  10 hua  staff         320 Jan  3 22:25 .
# drwxr-xr-x  23 hua  staff         736 Jan  2 10:30 ..
# -rw-r--r--   1 hua  staff   730097104 Jan  2 09:34 candidate_submission.parquet
# drwxr-xr-x   3 hua  staff          96 Jan  1 21:57 debug
# -rw-r--r--@  1 hua  staff   814184553 Jan  4 08:18 final_submission.csv
# drwxr-xr-x   8 hua  staff         256 Jan  2 07:00 parquet
# drwxr-xr-x   4 hua  staff         128 Dec 31 13:31 submission_data
# -rw-r--r--   1 hua  staff  1546537442 Jan  4 07:56 test_candidates.csv
# drwxr-xr-x   4 hua  staff         128 Dec 31 13:32 train_data
# -rw-r--r--   1 hua  staff  1125712760 Jan  3 21:47 val_candidates.csv
